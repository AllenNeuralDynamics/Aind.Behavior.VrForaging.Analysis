# %%
# IPython magig  tools
# %load_ext autoreload
# %autoreload 2

from aind_vr_foraging_analysis.utils.parsing import data_access
from aind_vr_foraging_analysis.utils.plotting import plotting_friction_experiment as f

# Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

sns.set_context('talk')

import warnings
pd.options.mode.chained_assignment = None  # Ignore SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

color1='#d95f02'
color2='#1b9e77'
color3='#7570b3'
color4='yellow'
odor_list_color = [color1, color2, color3, color4]

pdf_path = r'Z:\scratch\vr-foraging\sessions'
results_path = r'C:\Users\tiffany.ona\OneDrive - Allen Institute\Documents\VR foraging\experiments\batch 5 - learning\results'

color_dict_label = {'InterSite': '#808080',
    'InterPatch': '#b3b3b3', 
    'PatchZ': '#d95f02', 'PatchZB': '#d95f02', 
    'PatchB': '#d95f02','PatchA': '#7570b3', 
    'PatchC': '#1b9e77',
    'Alpha-pinene': '#1b9e77', 
    'Methyl Butyrate': '#7570b3', 
    'Amyl Acetate': '#d95f02', 
    'Fenchone': '#7570b3', 
    'patch_single': color1,
    'patch_delayed': color2,
    'patch_no_reward': color3,
     'S': color1,
    'D': color2,
    'N': color3,   
    }

label_dict = {**{
"InterSite": '#808080',
"InterPatch": '#b3b3b3'}, 
            **color_dict_label}
import os

# %%
mouse_list = ['789911', '789919', '789913', '789918', '789908']

# %%
date_string = "2025-4-14"

df = pd.DataFrame()
for mouse in mouse_list:
    session_paths = data_access.find_sessions_relative_to_date(
        mouse=mouse,
        date_string=date_string,
        when='on_or_after'
    )
    session_n = 0
    for session_path in session_paths:
        print(mouse, session_path)
        try:
            all_epochs, stream_data, data = data_access.load_session(
                session_path
            )
        except:
            print(f"Error loading {session_path.name}")
            continue
        
        stage = data['config'].streams.tasklogic_input.data['stage_name']
        if stage != 'data_collection':
            continue
        
        all_epochs['mouse'] = mouse
        all_epochs['session'] = session_path.name[7:17]
        all_epochs['session_n'] = session_n
        
        last_engaged_patch = all_epochs['patch_number'][all_epochs['skipped_count'] >= 5].min()
        if pd.isna(last_engaged_patch):
            last_engaged_patch = all_epochs['patch_number'].max()
        all_epochs['engaged'] = np.where(all_epochs['patch_number'] <= last_engaged_patch, 1, 0)
        session_n += 1
        
        df = pd.concat([all_epochs, df])
# Out:
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-14T200003Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-14T200003Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-15T201052Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-15T201052Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-16T200610Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-16T200610Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-17T203433Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-17T203433Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-18T200930Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-18T200930Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-21T191347Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-21T191347Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-22T200608Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-22T200608Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-23T200620Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-23T200620Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-24T201010Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-24T201010Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-25T200523Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-25T200523Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-28T200128Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-28T200128Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-29T202809Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-29T202809Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-04-30T201938Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-04-30T201938Z\behavior
# 789911 Z:\scratch\vr-foraging\data\789911\789911_2025-05-01T201708Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789911\789911_2025-05-01T201708Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-14T200459Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-14T200459Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-15T201101Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-15T201101Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-16T200557Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-16T200557Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-17T201009Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-17T201009Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-18T200919Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-18T200919Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-21T191213Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-21T191213Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-22T200038Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-22T200038Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-23T200629Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-23T200629Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-24T200624Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-24T200624Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-25T203151Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-25T203151Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-28T200045Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-28T200045Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-29T202849Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-29T202849Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-04-30T195903Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-04-30T195903Z\behavior
# 789919 Z:\scratch\vr-foraging\data\789919\789919_2025-05-01T201719Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789919\789919_2025-05-01T201719Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-14T161347Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-14T161347Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-15T164759Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-15T164759Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-16T161812Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-16T161812Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-17T161439Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-17T161439Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-18T163302Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-18T163302Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-21T162441Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-21T162441Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-22T161653Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-22T161653Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-23T162804Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-23T162804Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-24T165311Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-24T165311Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-25T161240Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-25T161240Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-28T163140Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-28T163140Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-29T163225Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-29T163225Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-04-30T161708Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-04-30T161708Z\behavior
# 789913 Z:\scratch\vr-foraging\data\789913\789913_2025-05-01T162918Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789913\789913_2025-05-01T162918Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-14T200513Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-14T200513Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-15T201115Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-15T201115Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-16T200729Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-16T200729Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-17T201046Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-17T201046Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-18T201009Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-18T201009Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-21T191239Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-21T191239Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-22T195911Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-22T195911Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-23T200702Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-23T200702Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-24T200755Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-24T200755Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-25T200503Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-25T200503Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-28T200446Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-28T200446Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-29T195520Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-29T195520Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-04-30T200259Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-04-30T200259Z\behavior
# 789918 Z:\scratch\vr-foraging\data\789918\789918_2025-05-01T201825Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789918\789918_2025-05-01T201825Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-14T175821Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-14T175821Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-15T182350Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-15T182350Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-16T183455Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-16T183455Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-17T182049Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-17T182049Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-18T181834Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-18T181834Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-21T174117Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-21T174117Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-22T175934Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-22T175934Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-23T182259Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789908\789908_2025-04-23T182259Z\behavior
# 789908 Z:\scratch\vr-foraging\data\789908\789908_2025-04-24T181838Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']

# %%
df['patch_label'] = df['patch_label'].replace({'PatchA': '90', 'PatchB': '60', 'PatchC': '0'})

# %%
df['rate_since_entry'] = df['cumulative_rewards'] / df['time_since_entry']
df['stops'] = df['site_number'] + 1
df['rate_stops'] = df['cumulative_rewards'] / df['stops']

# %%
window = 8
df_cum = pd.DataFrame()
for mouse in df.mouse.unique():
    for sn in df.loc[(df.mouse == mouse)].session_n.unique():
        print(mouse)
        df_session = df.loc[(df.mouse == mouse)&(df.session_n == sn)].copy()

        df_sorted = df_session.sort_values(['patch_number', 'site_number'])

        # Step 2: Within each patch_number, forward-fill the last reward time
        df_sorted['last_reward_time'] = (
            df_sorted
            .groupby('patch_number')['reward_onset_time']
            .transform(lambda x: x.ffill())
        )

        # If needed, restore original order
        df_final = df_sorted.sort_values('start_time')

        df_final['fixed_last_reward'] = df_final['last_reward_time'].shift(1)
        df_final['local_average_rate'] = 5 / (df_final['start_time']-df_final['fixed_last_reward'])

        # Make sure the dataframe is sorted correctly
        df_final = df_final.sort_values(['patch_number', 'site_number'])

        # Compute rolling average within patch, allowing fewer points at the start
        df_final['running_avg_rate'] = (
            df_final
            .groupby('patch_number')['is_reward']
            .rolling(window=window_size, min_periods=1)
            .mean()
            .reset_index(level=0, drop=True)
        )

        print(df_final.loc[(df_final.last_site == 1)&(df_final.site_number > 0)].groupby('patch_label').running_avg_rate.mean())
        df_cum  = pd.concat([df_final, df_cum], ignore_index=True)
        
df = df_cum.copy()

# %%
# Group the data
odor_labels = ['90', '60']

# Group the data as you described
patch_df = (
    # df[((df.odor_label != 'Ethyl Butyrate') & (df.site_number > 0))|((df.site_number > 1)&(df.odor_label == 'Ethyl Butyrate'))&(df['last_site'] == 1)]
    df.loc[(df['last_visit'] == 1)&(df.site_number > 0)]
    .groupby(['mouse', 'session_n', 'patch_label', 'patch_number'])
    .agg(
        site_number=('site_number', 'max'),
        reward_probability=('reward_probability', 'min'),
        stops=('site_number', 'max'),
        total_rewards=('cumulative_rewards', 'max'),
        consecutive_rewards = ('consecutive_rewards', 'max'),
        total_failures=('cumulative_failures', 'max'),
        consecutive_failures = ('consecutive_failures', 'max'), 
        friction=('torque_friction', 'max'), 
        rate_since_entry=('rate_since_entry', 'mean'), 
        rate_stops = ('rate_stops', 'mean'), 
        running_avg_rate = ('running_avg_rate', 'mean'), 
        local_average_rate = ('local_average_rate', 'mean')
        )
    .reset_index()
)
session_df = (
    patch_df
    .groupby(['mouse', 'session_n', 'patch_label'])
    .agg(site_number = ('site_number','sum'), 
            reward_probability = ('reward_probability','mean'), 
            stops = ('stops','mean'),
            total_stops = ('stops','sum'), 
            total_rewards = ('total_rewards','mean'),
            consecutive_rewards = ('consecutive_rewards','mean'),
            total_failures = ('total_failures','mean'),
            consecutive_failures = ('consecutive_failures','mean'), 
            patch_number = ('patch_number','nunique'), 
            total_water = ('total_water','sum'),
            friction = ('friction', 'mean'),
            rate_since_entry=('rate_since_entry', 'mean'), 
            rate_stops = ('rate_stops', 'mean'), 
            running_avg_rate = ('running_avg_rate', 'mean'), 
            local_average_rate = ('local_average_rate', 'mean')
         )
    .reset_index()
)

# These df summarizes metrics for each mouse (averages all sessions and all patches withing that session)
mouse_df = ( 
        patch_df
        .groupby(['mouse','patch_label'])
        .agg({'rate_since_entry': 'mean',
          'reward_probability': 'mean', 
          'rate_stops': 'mean', 
          'running_avg_rate': 'mean',
          'local_average_rate': 'mean'
              })
        .reset_index()
)

# %%
for mouse in session_df.mouse.unique():
    with PdfPages(results_path+f'/summary_results_control_per_mouse_{mouse}.pdf') as pdf:
        print(mouse)
        f.summary_main_variables(session_df.loc[session_df.mouse == mouse], 'control', condition='session_n', save=pdf, odor_labels=['90','60'])

# %%
# for experiment in general_df.experiment.unique():
with PdfPages(results_path+f'/summary_general_results_control_all.pdf') as pdf:
    f.summary_main_variables(mouse_df, 'N = 23 mice', condition='mouse', save=pdf, odor_labels=['90','60'])

# %%
## Difference between the two patches per mouse
mice = df['mouse'].unique()
n_mice = len(mice)
n_cols = 5  # adjust number of columns as needed
n_rows = int(np.ceil(n_mice / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4*n_cols, 4*n_rows), squeeze=False, sharey=True)

for idx, mouse in enumerate(mice):
    row = idx // n_cols
    col = idx % n_cols
    ax = axes[row, col]

    mouse_group = session_df[session_df['mouse'] == mouse]

    # Plot boxplot
    sns.boxplot(
        x='patch_label',
        y=variable,
        palette=color_dict_label,
        data=mouse_group,
        order=odor_labels,
        zorder=10,
        width=0.7,
        ax=ax,
        fliersize=0
    )

    # Plot session lines
    f.plot_lines(
        data=mouse_group,
        ax=ax,
        variable=variable,
        one_line='session_n',
        order=odor_labels
    )

    ax.set_title(f'Mouse {mouse}')
    ax.set_xlabel('')
    ax.set_xticks([0, 1])
    ax.set_xticklabels(['Odor 1', 'Odor 2'])
    # ax.set_ylabel('Rate since entry')

    sns.despine(ax=ax)

# Turn off empty axes
for idx in range(n_mice, n_rows * n_cols):
    row = idx // n_cols
    col = idx % n_cols
    axes[row, col].axis('off')

fig.tight_layout()
plt.show()
fig.savefig(results_path + f'/grid_mouse_y_{variable}_x_patch_label.pdf', bbox_inches='tight')
