# %%
# IPython magig  tools
# %load_ext autoreload
# %autoreload 2

# Plotting libraries
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator

import seaborn as sns
import math

color1='#d95f02'
color2='#1b9e77'
color3='#7570b3'
color4='yellow'
odor_list_color = [color1, color2, color3, color4]
# sns.set_context('talk')

pdf_path = r'Z:\scratch\vr-foraging\sessions'
base_path = 'Z:/scratch/vr-foraging/data/'
results_path = r'C:\Users\tiffany.ona\OneDrive - Allen Institute\Documents\VR foraging\experiments\batch 5 - learning\results'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set another publication style with different aesthetic choices
sns.set_theme(style="ticks", context="paper", palette="muted")

# Update rcParams for a sleek, publication-ready appearance
plt.rcParams.update({
    "figure.figsize": (2.5, 2),          # Slightly bigger for clarity
    "axes.labelsize": 8,              # Axes label font size
    "axes.titlesize": 9,              # Title font size
    "xtick.labelsize": 7,              # X-axis tick font size
    "ytick.labelsize": 7,              # Y-axis tick font size
    "legend.fontsize": 7,              # Legend font size
    "font.family": "serif",            # Serif font for a professional look
    "pdf.fonttype": 42,                # Ensure editable fonts in Illustrator
    "ps.fonttype": 42,
    "axes.spines.top": False,          # Remove top spine for cleaner look
    "axes.spines.right": False,        # Remove right spine for cleaner look
    "axes.linewidth": 0.6,            # Thin axes lines
    "lines.linewidth": 1,             # Line thickness
    "xtick.major.width": 0.6,         # Thicker major ticks
    "ytick.major.width": 0.6,         # Thicker major ticks
    "xtick.major.size": 3,            # Larger major ticks
    "ytick.major.size": 3,            # Larger major ticks
    "xtick.minor.size": 2,            # Minor ticks size
    "ytick.minor.size": 2,            # Minor ticks size
    "xtick.minor.width": 0.5,         # Minor ticks width
    "ytick.minor.width": 0.5          # Minor tick width
})

# %%
import pandas as pd
import numpy as np

plt.plot([0,600], [0,1], color='black', linestyle='--', linewidth=1)
plt.xlabel('Distance (cm)')
plt.ylabel('Relative time spent \n in the interpatch')
plt.plot([50], [0.08], 'o', color=color1, markersize=4)
plt.plot([150], [0.25], 'o', color=color2, markersize=4)
plt.plot([450], [0.75], 'o', color=color3, markersize=4)
plt.plot([600], [1], 'o', color=color4, markersize=4)
plt.plot([300], [0.5], 'x', color='black', markersize=10)
