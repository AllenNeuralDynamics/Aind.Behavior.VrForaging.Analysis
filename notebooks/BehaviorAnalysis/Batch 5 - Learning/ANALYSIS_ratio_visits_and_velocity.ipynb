# %%
# IPython magig  tools
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path

from aind_vr_foraging_analysis.utils.parsing import data_access
import aind_vr_foraging_analysis.utils.plotting as plotting

# Plotting libraries
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

import seaborn as sns
import pandas as pd
import numpy as np

sns.set_context('talk')

import warnings
pd.options.mode.chained_assignment = None  # Ignore SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

color1='#d95f02'
color2='#1b9e77'
color3='#7570b3'
color4='yellow'
odor_list_color = [color1, color2, color3, color4]

pdf_path = r'Z:\scratch\vr-foraging\sessions'
figures = r'C:\Users\tiffany.ona\OneDrive - Allen Institute\Documents\VR foraging\experiments\batch 5 - learning\results'

color_dict_label = {'InterSite': '#808080',
    'InterPatch': '#b3b3b3', 
    'PatchZ': '#d95f02', 'PatchZB': '#d95f02', 
    'PatchB': '#d95f02','PatchA': '#7570b3', 
    'PatchC': '#1b9e77',
    'Alpha-pinene': '#1b9e77', 
    'Methyl Butyrate': '#7570b3', 
    'Amyl Acetate': '#d95f02', 
    'Fenchone': '#7570b3', 
    'patch_single': color1,
    'patch_delayed': color2,
    'patch_no_reward': color3,
    }

label_dict = {**{
"InterSite": '#808080',
"InterPatch": '#b3b3b3'}, 
            **color_dict_label}

# %%
def grid_mouse_y_fraction_attemped_x_session_n(df):
    session_ns = sorted(df.mouse.unique())
    n_sessions = len(session_ns)

    # Determine subplot grid size
    n_cols = int(np.ceil(np.sqrt(n_sessions)))
    n_rows = int(np.ceil(n_sessions / n_cols))

    # Create figure
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 4 * n_rows), squeeze=False)

    for idx, sn in enumerate(session_ns):
        row = idx // n_cols
        col = idx % n_cols
        ax = axes[row, col]

        df_sn = df[(df.mouse == sn)]

        # InterSite
        sns.lineplot(data=df_sn, x='session_n', y='fraction_visited', hue='patch_label', palette=color_dict_label, ax=ax, legend=False, lw=2, alpha=0.5)

        ax.set_title(f"{sn}")
        ax.set_xlabel("Sesson number")
        ax.set_ylabel("Fraction visited")
        
    plt.legend(loc='upper right')
    # Remove unused axes if grid is larger than number of sessions
    for j in range(len(session_ns), n_rows * n_cols):
        fig.delaxes(axes[j // n_cols][j % n_cols])

    sns.despine()
    plt.tight_layout()
    plt.subplots_adjust(top=0.93)
    plt.show()
    # fig.savefig(os.path.join(foraging_figures, f'{mouse}_grid_session_speed_epochs.pdf'), dpi=300, bbox_inches='tight')

# %%
trainer_dict = {'754574': 'Katrina',
                '789914': 'Katrina', 
                '789915': 'Katrina', 
                '789923': 'Katrina', 
                '789917' : 'Katrina', 
                '789909': 'Huy',
                '789910': 'Huy',
                '789921': 'Huy',
                '789907': 'Olivia',
                '789903': 'Olivia',
                '789925': 'Olivia',
                '789924': 'Olivia',
                '789926': 'Olivia',
}      
mouse_list = trainer_dict.keys()

# %%
date_string = "2025-4-14"

sum_df = pd.DataFrame()
summary_df = pd.DataFrame()
for mouse in mouse_list:
    session_paths = data_access.find_sessions_relative_to_date(
        mouse=mouse,
        date_string=date_string,
        when='on_or_after'
    )
    session_n = 0
    for session_path in session_paths:
        print(mouse, session_path)
        try:
            all_epochs, stream_data, data = data_access.load_session(
                session_path
            )
        except:
            print(f"Error loading {session_path.name}")
            continue
        all_epochs['mouse'] = mouse
        patch_df = all_epochs.groupby(['mouse','patch_label']).agg({'patch_number': 'nunique'}).reset_index()
        patch_df['visited'] = all_epochs.loc[(all_epochs.site_number == 0)&(all_epochs.is_choice == 1)].groupby(['mouse','patch_label']).agg({'patch_number': 'nunique'}).reset_index()['patch_number']
        patch_df['fraction_visited'] = patch_df['visited'] / patch_df['patch_number']
        patch_df['session'] = session_path.name
        patch_df['session_n'] = session_n
        session_n += 1
        sum_df = pd.concat([patch_df, sum_df])
        
        summary_df = pd.concat([all_epochs, summary_df])
# Out:
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-14T162924Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-14T162924Z\behavior
# load_session_data: 76.78 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.54 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-15T165125Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-15T165125Z\behavior
# load_session_data: 4.06 s
# parse_dataframe: 0.57 s
# ContinuousData: 0.76 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-16T161805Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-16T161805Z\behavior
# load_session_data: 2.72 s
# parse_dataframe: 0.50 s
# ContinuousData: 0.67 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-17T161413Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-17T161413Z\behavior
# load_session_data: 2.84 s
# parse_dataframe: 0.53 s
# ContinuousData: 0.75 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-18T161553Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-18T161553Z\behavior
# load_session_data: 3.18 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.70 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-21T160526Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-21T160526Z\behavior
# load_session_data: 2.65 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.64 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-18T234702Z
# Loading data from:  ['behavior']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-18T234702Z\behavior
# load_session_data: 2.56 s
# parse_dataframe: 0.10 s
# ContinuousData: 0.27 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-22T161645Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-22T161645Z\behavior
# load_session_data: 2.65 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.74 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-23T162755Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-23T162755Z\behavior
# load_session_data: 2.78 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.70 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-24T165303Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-24T165303Z\behavior
# load_session_data: 2.74 s
# parse_dataframe: 0.43 s
# ContinuousData: 0.59 s
# 754574 Z:\scratch\vr-foraging\data\754574\754574_2025-04-25T160731Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\754574\754574_2025-04-25T160731Z\behavior
# load_session_data: 2.76 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.67 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-14T161143Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-14T161143Z\behavior
# load_session_data: 2.70 s
# parse_dataframe: 0.57 s
# ContinuousData: 0.82 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-15T170104Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-15T170104Z\behavior
# load_session_data: 2.61 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.62 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-16T161723Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-16T161723Z\behavior
# Config file is empty or corrupted.
# load_session_data: 2.54 s
# parse_dataframe: 0.30 s
# ContinuousData: 0.51 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-17T161507Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-17T161507Z\behavior
# load_session_data: 2.62 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.63 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-16T165818Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-16T165818Z\behavior
# load_session_data: 2.51 s
# parse_dataframe: 0.30 s
# ContinuousData: 0.43 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-18T161516Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-18T161516Z\behavior
# load_session_data: 2.65 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.62 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-21T160404Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-21T160404Z\behavior
# load_session_data: 2.62 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.68 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-22T161606Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-22T161606Z\behavior
# load_session_data: 2.83 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.60 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-23T162705Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-23T162705Z\behavior
# load_session_data: 2.69 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.64 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-24T165219Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-24T165219Z\behavior
# load_session_data: 2.69 s
# parse_dataframe: 0.43 s
# ContinuousData: 0.60 s
# 789914 Z:\scratch\vr-foraging\data\789914\789914_2025-04-25T160642Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789914\789914_2025-04-25T160642Z\behavior
# load_session_data: 2.67 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.62 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-14T161154Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-14T161154Z\behavior
# load_session_data: 2.84 s
# parse_dataframe: 0.60 s
# ContinuousData: 0.84 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-15T170022Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-15T170022Z\behavior
# load_session_data: 2.64 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.70 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-16T165609Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-16T165609Z\behavior
# load_session_data: 2.64 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.48 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-17T161156Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-17T161156Z\behavior
# load_session_data: 2.77 s
# parse_dataframe: 0.49 s
# ContinuousData: 0.68 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-18T161508Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-18T161508Z\behavior
# load_session_data: 2.79 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.58 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-21T160413Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-21T160413Z\behavior
# load_session_data: 2.80 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.58 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-22T161614Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-22T161614Z\behavior
# load_session_data: 2.68 s
# parse_dataframe: 0.40 s
# ContinuousData: 0.60 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-23T162714Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-23T162714Z\behavior
# load_session_data: 2.77 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.68 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-24T165228Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-24T165228Z\behavior
# load_session_data: 2.72 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.58 s
# 789915 Z:\scratch\vr-foraging\data\789915\789915_2025-04-25T160650Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789915\789915_2025-04-25T160650Z\behavior
# load_session_data: 2.68 s
# parse_dataframe: 0.40 s
# ContinuousData: 0.59 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-14T161222Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-14T161222Z\behavior
# load_session_data: 2.76 s
# parse_dataframe: 0.53 s
# ContinuousData: 0.80 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-15T170313Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-15T170313Z\behavior
# load_session_data: 2.73 s
# parse_dataframe: 0.35 s
# ContinuousData: 0.42 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-15T174529Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-15T174529Z\behavior
# load_session_data: 2.55 s
# parse_dataframe: 0.22 s
# ContinuousData: 0.40 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-16T161753Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-16T161753Z\behavior
# load_session_data: 2.62 s
# parse_dataframe: 0.49 s
# ContinuousData: 0.64 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-17T161400Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-17T161400Z\behavior
# load_session_data: 2.80 s
# parse_dataframe: 0.56 s
# ContinuousData: 0.62 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-18T161535Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-18T161535Z\behavior
# load_session_data: 2.71 s
# parse_dataframe: 0.47 s
# ContinuousData: 0.61 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-21T160503Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-21T160503Z\behavior
# load_session_data: 2.62 s
# parse_dataframe: 0.47 s
# ContinuousData: 0.61 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-22T161634Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-22T161634Z\behavior
# load_session_data: 2.61 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.57 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-23T162736Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-23T162736Z\behavior
# load_session_data: 2.80 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.59 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-24T165247Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-24T165247Z\behavior
# load_session_data: 2.75 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.71 s
# 789923 Z:\scratch\vr-foraging\data\789923\789923_2025-04-25T160707Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789923\789923_2025-04-25T160707Z\behavior
# load_session_data: 2.60 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.61 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-14T161212Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-14T161212Z\behavior
# load_session_data: 2.66 s
# parse_dataframe: 0.53 s
# ContinuousData: 0.72 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-15T170142Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-15T170142Z\behavior
# load_session_data: 2.53 s
# parse_dataframe: 0.34 s
# ContinuousData: 0.44 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-15T174601Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-15T174601Z\behavior
# load_session_data: 2.69 s
# parse_dataframe: 0.27 s
# ContinuousData: 0.38 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-16T161743Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-16T161743Z\behavior
# load_session_data: 2.83 s
# parse_dataframe: 0.47 s
# ContinuousData: 0.61 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-17T161258Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-17T161258Z\behavior
# load_session_data: 3.14 s
# parse_dataframe: 0.49 s
# ContinuousData: 0.68 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-18T161526Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-18T161526Z\behavior
# load_session_data: 3.07 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.56 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-21T160513Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-21T160513Z\behavior
# load_session_data: 2.78 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.63 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-22T161626Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-22T161626Z\behavior
# load_session_data: 3.06 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.63 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-23T162726Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-23T162726Z\behavior
# load_session_data: 3.04 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.62 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-24T165238Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-24T165238Z\behavior
# load_session_data: 3.00 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.58 s
# 789917 Z:\scratch\vr-foraging\data\789917\789917_2025-04-25T160659Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789917\789917_2025-04-25T160659Z\behavior
# load_session_data: 2.94 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.57 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-14T201855Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-14T201855Z\behavior
# load_session_data: 3.07 s
# parse_dataframe: 0.49 s
# ContinuousData: 0.66 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-15T201024Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-15T201024Z\behavior
# load_session_data: 2.93 s
# parse_dataframe: 0.47 s
# ContinuousData: 0.64 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-16T200653Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-16T200653Z\behavior
# load_session_data: 2.91 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.64 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-17T200857Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-17T200857Z\behavior
# load_session_data: 3.00 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.72 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-18T200953Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-18T200953Z\behavior
# load_session_data: 2.95 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.67 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-21T191321Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-21T191321Z\behavior
# load_session_data: 2.89 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.59 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-22T200720Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-22T200720Z\behavior
# load_session_data: 2.83 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.63 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-23T204507Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-23T204507Z\behavior
# load_session_data: 2.72 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.56 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-24T200651Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-24T200651Z\behavior
# load_session_data: 2.58 s
# parse_dataframe: 0.57 s
# ContinuousData: 0.56 s
# 789909 Z:\scratch\vr-foraging\data\789909\789909_2025-04-25T201413Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789909\789909_2025-04-25T201413Z\behavior
# load_session_data: 2.43 s
# parse_dataframe: 0.33 s
# ContinuousData: 0.48 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-14T200140Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-14T200140Z\behavior
# load_session_data: 2.38 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.57 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-15T201037Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-15T201037Z\behavior
# load_session_data: 2.35 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.56 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-16T200642Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-16T200642Z\behavior
# load_session_data: 2.20 s
# parse_dataframe: 0.34 s
# ContinuousData: 0.45 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-17T200851Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-17T200851Z\behavior
# load_session_data: 2.34 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.55 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-18T200943Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-18T200943Z\behavior
# load_session_data: 2.33 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.54 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-21T191313Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-21T191313Z\behavior
# load_session_data: 2.32 s
# parse_dataframe: 0.35 s
# ContinuousData: 0.48 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-22T200704Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-22T200704Z\behavior
# load_session_data: 2.62 s
# parse_dataframe: 0.35 s
# ContinuousData: 0.51 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-23T200642Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-23T200642Z\behavior
# load_session_data: 2.58 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.55 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-24T200635Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-24T200635Z\behavior
# load_session_data: 2.68 s
# parse_dataframe: 0.33 s
# ContinuousData: 0.70 s
# 789910 Z:\scratch\vr-foraging\data\789910\789910_2025-04-25T200448Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789910\789910_2025-04-25T200448Z\behavior
# load_session_data: 3.13 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.67 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-14T200152Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-14T200152Z\behavior
# load_session_data: 2.98 s
# parse_dataframe: 0.40 s
# ContinuousData: 0.54 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-15T201128Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-15T201128Z\behavior
# load_session_data: 2.47 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.50 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-16T200716Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-16T200716Z\behavior
# load_session_data: 3.66 s
# parse_dataframe: 0.33 s
# ContinuousData: 0.52 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-17T201056Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-17T201056Z\behavior
# load_session_data: 2.43 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.55 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-18T201057Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-18T201057Z\behavior
# load_session_data: 2.84 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.57 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-21T191228Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-21T191228Z\behavior
# load_session_data: 2.84 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.50 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-22T195901Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-22T195901Z\behavior
# load_session_data: 2.75 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.50 s
# 789921 Z:\scratch\vr-foraging\data\789921\789921_2025-04-23T200711Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789921\789921_2025-04-23T200711Z\behavior
# load_session_data: 2.75 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.57 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-14T175728Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-14T175728Z\behavior
# load_session_data: 2.61 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.50 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-15T182332Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-15T182332Z\behavior
# load_session_data: 2.75 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.53 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-16T181803Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-16T181803Z\behavior
# load_session_data: 2.44 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.55 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-17T175003Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-17T175003Z\behavior
# load_session_data: 2.40 s
# parse_dataframe: 0.35 s
# ContinuousData: 0.45 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-18T182522Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-18T182522Z\behavior
# load_session_data: 2.48 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.50 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-21T174058Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-21T174058Z\behavior
# load_session_data: 2.50 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.48 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-22T175918Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-22T175918Z\behavior
# load_session_data: 2.47 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.48 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-23T180922Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-23T180922Z\behavior
# load_session_data: 2.39 s
# parse_dataframe: 0.40 s
# ContinuousData: 0.51 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-24T181053Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-24T181053Z\behavior
# load_session_data: 2.50 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.44 s
# 789907 Z:\scratch\vr-foraging\data\789907\789907_2025-04-25T181442Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789907\789907_2025-04-25T181442Z\behavior
# load_session_data: 2.38 s
# parse_dataframe: 0.38 s
# ContinuousData: 0.46 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-14T175307Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-14T175307Z\behavior
# load_session_data: 2.69 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.52 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-15T182649Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-15T182649Z\behavior
# load_session_data: 2.70 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.52 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-16T183508Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-16T183508Z\behavior
# load_session_data: 2.73 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.46 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-17T175215Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-17T175215Z\behavior
# load_session_data: 2.72 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.47 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-18T181905Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-18T181905Z\behavior
# load_session_data: 2.84 s
# parse_dataframe: 0.38 s
# ContinuousData: 0.52 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-21T174231Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-21T174231Z\behavior
# load_session_data: 2.87 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.45 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-22T175830Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-22T175830Z\behavior
# load_session_data: 2.81 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.47 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-23T181115Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-23T181115Z\behavior
# load_session_data: 2.64 s
# parse_dataframe: 0.38 s
# ContinuousData: 0.49 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-24T181247Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-24T181247Z\behavior
# load_session_data: 2.85 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.47 s
# 789903 Z:\scratch\vr-foraging\data\789903\789903_2025-04-25T181628Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789903\789903_2025-04-25T181628Z\behavior
# load_session_data: 2.82 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.50 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-14T175251Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-14T175251Z\behavior
# load_session_data: 2.91 s
# parse_dataframe: 0.43 s
# ContinuousData: 0.52 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-15T182553Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-15T182553Z\behavior
# load_session_data: 2.87 s
# parse_dataframe: 0.43 s
# ContinuousData: 0.52 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-16T181911Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-16T181911Z\behavior
# load_session_data: 2.78 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.49 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-17T175240Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-17T175240Z\behavior
# load_session_data: 2.83 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.47 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-18T181924Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-18T181924Z\behavior
# load_session_data: 2.83 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.52 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-21T174214Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-21T174214Z\behavior
# load_session_data: 2.77 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.47 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-22T175859Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-22T175859Z\behavior
# load_session_data: 2.86 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.47 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-23T181159Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-23T181159Z\behavior
# load_session_data: 2.80 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.48 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-24T181203Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-24T181203Z\behavior
# load_session_data: 2.80 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.47 s
# 789925 Z:\scratch\vr-foraging\data\789925\789925_2025-04-25T181608Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789925\789925_2025-04-25T181608Z\behavior
# load_session_data: 2.86 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.47 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-14T175107Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-14T175107Z\behavior
# load_session_data: 2.73 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.52 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-15T182953Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-15T182953Z\behavior
# load_session_data: 2.75 s
# parse_dataframe: 0.38 s
# ContinuousData: 0.48 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-16T182143Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-16T182143Z\behavior
# load_session_data: 2.78 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.48 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-17T175802Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-17T175802Z\behavior
# load_session_data: 2.77 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.49 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-18T182046Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-18T182046Z\behavior
# load_session_data: 2.88 s
# parse_dataframe: 0.42 s
# ContinuousData: 0.50 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-21T174402Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-21T174402Z\behavior
# load_session_data: 2.78 s
# parse_dataframe: 0.41 s
# ContinuousData: 0.48 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-22T180044Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-22T180044Z\behavior
# load_session_data: 2.94 s
# parse_dataframe: 0.36 s
# ContinuousData: 0.46 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-23T183014Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-23T183014Z\behavior
# load_session_data: 3.05 s
# parse_dataframe: 0.48 s
# ContinuousData: 0.59 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-24T181403Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-24T181403Z\behavior
# load_session_data: 3.41 s
# parse_dataframe: 0.53 s
# ContinuousData: 0.61 s
# 789924 Z:\scratch\vr-foraging\data\789924\789924_2025-04-25T182223Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789924\789924_2025-04-25T182223Z\behavior
# load_session_data: 3.09 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.55 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-14T175034Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-14T175034Z\behavior
# load_session_data: 3.27 s
# parse_dataframe: 0.55 s
# ContinuousData: 0.59 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-15T182833Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-15T182833Z\behavior
# load_session_data: 3.08 s
# parse_dataframe: 0.39 s
# ContinuousData: 0.53 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-16T182120Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-16T182120Z\behavior
# load_session_data: 2.92 s
# parse_dataframe: 0.37 s
# ContinuousData: 0.48 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-17T175345Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-17T175345Z\behavior
# load_session_data: 2.98 s
# parse_dataframe: 0.38 s
# ContinuousData: 0.51 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-18T182111Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-18T182111Z\behavior
# load_session_data: 3.04 s
# parse_dataframe: 0.47 s
# ContinuousData: 0.62 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-21T174420Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-21T174420Z\behavior
# load_session_data: 3.24 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.65 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-22T180100Z
# Loading data from:  ['behavior', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-22T180100Z\behavior
# load_session_data: 3.11 s
# parse_dataframe: 0.45 s
# ContinuousData: 0.62 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-23T181314Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-23T181314Z\behavior
# load_session_data: 3.43 s
# parse_dataframe: 0.44 s
# ContinuousData: 0.62 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-24T181340Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-24T181340Z\behavior
# load_session_data: 3.06 s
# parse_dataframe: 0.46 s
# ContinuousData: 0.60 s
# 789926 Z:\scratch\vr-foraging\data\789926\789926_2025-04-25T182319Z
# Loading data from:  ['behavior', 'behavior-videos', 'rig.json', 'session.json']
# Loading data from:  Z:\scratch\vr-foraging\data\789926\789926_2025-04-25T182319Z\behavior
# load_session_data: 3.33 s
# parse_dataframe: 0.50 s
# ContinuousData: 0.62 s

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 10), gridspec_kw={'width_ratios': [3, 1]}, sharey=True)

ax = axes[0][0]
df = summary_df.groupby(['mouse', 'session', 'is_choice']).duration_epoch.median().reset_index()
sns.barplot(data=df, x='mouse', y='duration_epoch', hue='is_choice', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.despine()
ax.set_ylabel('Duration of odor site visit (s)')

ax = axes[0][1]
sns.barplot(data=df, x='is_choice', y='duration_epoch', hue='is_choice', ax=ax)
ax.set_xlabel('Stop')

ax = axes[1][0]
df = summary_df.loc[summary_df.is_choice ==1].groupby(['mouse', 'session', 'is_reward']).duration_epoch.median().reset_index()
sns.barplot(data=df, x='mouse', y='duration_epoch', hue='is_reward', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.despine()
ax.set_title('Duration of odor site visit for stops')
ax.set_ylabel('Duration of odor site visit (s)')

ax = axes[1][1]
sns.barplot(data=df, x='is_reward', y='duration_epoch', hue='is_reward', ax=ax)
ax.set_xlabel('Reward')

plt.tight_layout()

# %%
grid_mouse_y_fraction_attemped_x_session_n(sum_df)
# Out:
#      mouse      patch_label  patch_number  visited  fraction_visited  \
# 0   789926    patch_delayed            63     23.0          0.365079
# 1   789926  patch_no_reward            18     14.0          0.777778
# 2   789926     patch_single            45     42.0          0.933333
# 0   789926    patch_delayed            42     15.0          0.357143
# 1   789926  patch_no_reward            20     17.0          0.850000
# ..     ...              ...           ...      ...               ...
# 1   754574  patch_no_reward            56      9.0          0.160714
# 2   754574     patch_single            54     54.0          1.000000
# 0   754574    patch_delayed            36     14.0          0.388889
# 1   754574  patch_no_reward            31      9.0          0.290323
# 2   754574     patch_single            43     43.0          1.000000
#
#                       session
# 0   789926_2025-04-25T182319Z
# 1   789926_2025-04-25T182319Z
# 2   789926_2025-04-25T182319Z
# 0   789926_2025-04-24T181340Z
# 1   789926_2025-04-24T181340Z
# ..                        ...
# 1   754574_2025-04-15T165125Z
# 2   754574_2025-04-15T165125Z
# 0   754574_2025-04-14T162924Z
# 1   754574_2025-04-14T162924Z
# 2   754574_2025-04-14T162924Z
#
# [368 rows x 6 columns]
