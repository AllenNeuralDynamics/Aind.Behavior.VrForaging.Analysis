# %%
# IPython magig  tools
# %load_ext autoreload
# %autoreload 2

# Plotting libraries
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator

import seaborn as sns
import pandas as pd
import numpy as np
import math

color1='#d95f02'
color2='#1b9e77'
color3='#7570b3'
color4='yellow'
odor_list_color = [color1, color2, color3, color4]
sns.set_context('talk')
plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial"]
})

pdf_path = r'Z:\scratch\vr-foraging\sessions'
base_path = 'Z:/scratch/vr-foraging/data/'
results_path = r'C:\Users\tiffany.ona\OneDrive - Allen Institute\Documents\VR foraging\experiments\batch 5 - learning\results'

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4))
marker = 'o'
max_p = 1
ax1 = ax[0]
# Generate x values
x = np.linspace(0, 10, 10)  # Generate 100 points between 0 and 5
y = [max_p,0,0,0,0,0,0,0,0,0]
ax1.plot(x, y, color=color1, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
ax1.set_title('Patch Single')
specific_ticks = [0, 0.5 , 1]
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))

ax1 = ax[1]
x = np.linspace(0, 10, 10)  # Generate 100 points between 0 and 5
y = [0,max_p,max_p,max_p,0,0,0,0,0,0]
ax1.plot(x, y, color=color2, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
ax1.set_title('Patch Delayed')
specific_ticks = [0, 0.5 , 1]
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))

ax1 = ax[2]
x = np.linspace(0, 10, 10)  # Generate 100 points between 0 and 5
y = np.repeat(0,10)
ax1.plot(x, y, color=color3, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
specific_ticks = [0, 0.5 , 1]
ax1.set_title('Patch No reward')
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))

specific_ticks = [0, 5 , 10]
ax1.xaxis.set_major_locator(FixedLocator(specific_ticks))

sns.despine()
plt.tight_layout()
fig.savefig(results_path+r'\batch5_schematics_task.svg', dpi=300)

# %% [markdown]
# ### **Version 2** - Some ambiguity in the first stop of delayed patch

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4.5))
marker = 'o'
max_p = 1
ax1 = ax[0]
# Generate x values
x = np.linspace(1, 11, 10)  # Generate 100 points between 0 and 5
y = [max_p,0,0,0,0,0,0,0,0,0]
ax1.plot(x, y, color=color1, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
ax1.set_title('Patch Single')
specific_ticks = [0, 0.5 , 1]
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))
specific_ticks = [1, 4, 7, 10]
ax1.xaxis.set_major_locator(FixedLocator(specific_ticks))

ax1 = ax[1]
y = [0.5,max_p,max_p,max_p,0,0,0,0,0,0]
ax1.plot(x, y, color=color2, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
ax1.set_title('Patch Delayed')
specific_ticks = [0, 0.5 , 1]
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))
specific_ticks = [1, 4, 7, 10]
ax1.xaxis.set_major_locator(FixedLocator(specific_ticks))

ax1 = ax[2]
y = np.repeat(0,10)
ax1.plot(x, y, color=color3, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
specific_ticks = [0, 0.5 , 1]
ax1.set_title('Patch No reward')
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))
specific_ticks = [1, 4, 7, 10]
ax1.xaxis.set_major_locator(FixedLocator(specific_ticks))

sns.despine()
plt.tight_layout()
fig.savefig(results_path+r'\batch5_schematics_task_v2.svg', dpi=300)

# %% [markdown]
# #### Collapsed schematics

# %%
fig, ax = plt.subplots(1, 1, figsize=(4.5,4.5))
marker = 'o'
max_p = 1
ax1 = ax
# Generate x values
x = np.linspace(1, 11, 10)  # Generate 100 points between 0 and 5
y = [max_p,0,0,0,0,0,0,0,0,0]
ax1.plot(x, y, color=color1, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,10.5)
specific_ticks = [0, 1]
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))
specific_ticks = [1, 4, 7, 10]
ax1.xaxis.set_major_locator(FixedLocator(specific_ticks))

ax1 = ax
y = [0.5,max_p,max_p,max_p,0,0,0,0,0,0]
ax1.plot(x, y, color=color2, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')


ax1 = ax
y = np.repeat(0,10)
ax1.plot(x, y, color=color3, marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')

sns.despine()
plt.tight_layout()
fig.savefig(results_path+r'\batch5_schematics_task_v2_collapsed.svg', dpi=300)

# %% [markdown]
# ### **Shaping depletion**

# %%
fig, ax = plt.subplots(1, 1, figsize=(4,4))
marker = 'o'
max_p = 0.7
ax1 = ax
# Generate x values
x = np.linspace(0, 13, 13)  # Generate 100 points between 0 and 5
y = [max_p,max_p,max_p,max_p,max_p,max_p,max_p,max_p,max_p,max_p, 0, 0, 0]
ax1.plot(x, y, color='black', marker=marker)
ax1.set_xlabel('Stops')
ax1.set_ylabel('P(reward)')
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(-0.5,13.5)
specific_ticks = [0, 0.5 , 1]
ax1.yaxis.set_major_locator(FixedLocator(specific_ticks))
sns.despine()
